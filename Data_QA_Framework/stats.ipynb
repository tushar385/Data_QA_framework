# %% [markdown]
# ## Reload notebook

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Necessary Imports

# %%
from data_validations.table_access import table_access
from data_validations.eda import generate_eda_summary
from data_validations.mom_data_validation import generate_mom_summary

with open('tables_list.txt', 'r') as file: 
    exec(file.read())

# %% [markdown]
# ### 1. Table_access check

# %%
table_access(
    (google_raw_tables, "raw"),
    (google_intermedia_table, "intermedia")
)
# Out:
# [
#   {
#     "source": "raw",
#     "status_sign": "✅",
#     "status": "success",
#     "table_name": "PROD_TAPINTEL.PUBLIC.TBL__ADWORDS_CGN",
#     "row_count": 2523765,
#     "error_message": null,
#     "timestamp": "2025-05-29T10:47:30Z"
#   },
#   {
#     "source": "raw",
#     "status_sign": "✅",
#     "status": "success",
#     "table_name": "PROD_TAPINTEL.PUBLIC.TBL__ADWORDS_CGN_DATA",
#     "row_count": 541121884,
#     "error_message": null,
#     "timestamp": "2025-05-29T10:47:31Z"
#   },
#   {
#     "source": "raw",
#     "status_sign": "✅",
#     "status": "success",
#     "table_name": "PROD_TAPINTEL.PUBLIC.TBL__ADWORDS_ADGROUP",
#     "row_count": 20516500,
#     "error_message": null,
#     "timestamp": "2025-05-29T10:47:31Z"
#   },
#   {
#     "source": "raw",
#     "status_sign": "✅",
#     "status": "success",
#     "table_name": "PROD_TAPINTEL.PUBLIC.TBL__ADWORDS_ADGROUP_DATA",
#     "row_count": 2344857178,
#     "error_message": null,
# ...

# %% [markdown]
# ### 2. EDA

# %%
generate_eda_summary(
    (google_raw_tables, "raw"),
    (google_intermedia_table, "intermedia")
    # (test, "intermedia")
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 generate_eda_summary(
#       2     (google_raw_tables, "raw"),
#       3     (google_intermedia_table, "intermedia")
#       4     # (test, "intermedia")
#       5 )
#
# File ~/Documents/tap/Data_QA_Framework/data_validations/eda.py:92, in generate_eda_summary(*table_sources)
#      89 final_query = f'''SELECT {', '.join(agg_clauses)} FROM {table_fqn}'''
#      91 # Step 3: Execute and parse result
# ---> 92 cursor.execute(final_query)
#      93 row = cursor.fetchone()
#      94 raw_columns = [desc[0] for desc in cursor.description]
#
# ...

# %% [markdown]
# ### 3.MOM data validation

# %%
generate_mom_summary(
    (google_intermedia_table, "intermedia"),
    date_column='month_yr',
    date_column_type='TEXT'
)
# Out:
# [
#   {
#     "source": "intermedia",
#     "table_name": "TAPCLICKS_DATA_SEGMENTATION.PUBLIC.GOOGLE_ADS_GEO_MONTHLY",
#     "column": "CITY",
#     "Datatype": "TEXT",
#     "month": "2025-01-01",
#     "Unique COUNT": 45181,
#     "SUM": null,
#     "timestamp": "2025-05-29T12:42:11Z"
#   },
#   {
#     "source": "intermedia",
#     "table_name": "TAPCLICKS_DATA_SEGMENTATION.PUBLIC.GOOGLE_ADS_GEO_MONTHLY",
#     "column": "VERTICAL_ID",
#     "Datatype": "TEXT",
#     "month": "2025-01-01",
#     "Unique COUNT": 304,
#     "SUM": null,
#     "timestamp": "2025-05-29T12:42:11Z"
#   },
#   {
#     "source": "intermedia",
#     "table_name": "TAPCLICKS_DATA_SEGMENTATION.PUBLIC.GOOGLE_ADS_GEO_MONTHLY",
#     "column": "VERTICAL_NAME",
#     "Datatype": "TEXT",
#     "month": "2025-01-01",
#     "Unique COUNT": 304,
#     "SUM": null,
#     "timestamp": "2025-05-29T12:42:11Z"
#   },
#   {
#     "source": "intermedia",
# ...

# %%
generate_mom_summary(
    (google_raw_tables, "raw", "log_date", "TIMESTAMP"),
    (google_intermedia_table, "intermedia", "month_yr", "TEXT")
)
